# %% [markdown]
# # Параметрическое исследование M/M/c
# Сценарий сравнивает среднее время ожидания и загрузку каналов для разных
# значений интенсивности входящего потока и числа каналов обслуживания.

# %%
using DrWatson
@quickactivate "project"

using CSV
using CairoMakie

include(srcdir("QueueingModels.jl"))
using .QueueingModels

mkpath(datadir())
mkpath(plotsdir())

lambdas = [0.3, 0.6, 0.9]
channels = 1:6
mu = 0.5
num_customers = 3000
seed = 321

scan = run_mmc_parameter_scan(lambdas, channels, mu, num_customers, seed)

CSV.write(datadir("mmc_parameter_scan.csv"), scan)

save(plotsdir("mmc_wait_by_channels.png"), plot_mmc_wait_by_channels(scan))
save(plotsdir("mmc_wait_by_lambda.png"), plot_mmc_wait_by_lambda(scan))
save(plotsdir("mmc_utilization_heatmap.png"), plot_mmc_utilization_heatmap(scan))

println("M/M/c parameter scan completed")
println(scan)
# Out:
# M/M/c parameter scan completed
# 18×10 DataFrame
#  Row │ lambda   mu       c      rho      analytic_wq    sim_wq          analytic_w  sim_w       sim_utilization  sim_pwait
#      │ Float64  Float64  Int64  Float64  Float64        Float64         Float64     Float64     Float64          Float64
# ─────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#    1 │     0.3      0.5      1     0.6     3.0             3.11174         5.0         5.11708        0.587892   0.586333
#    2 │     0.3      0.5      2     0.3     0.197802        0.186095        2.1978      2.17209        0.294702   0.132333
#    3 │     0.3      0.5      3     0.2     0.0205479       0.0194592       2.02055     2.04741        0.20426    0.0273333
#    4 │     0.3      0.5      4     0.15    0.00205066      0.00200172      2.00205     1.94053        0.145112   0.00366667
#    5 │     0.3      0.5      5     0.12    0.000183691     0.000117352     2.00018     2.05346        0.122637   0.000333333
#    6 │     0.3      0.5      6     0.1     1.4635e-5       0.0             2.00001     1.97327        0.0973821  0.0
#    7 │     0.6      0.5      1     1.2   Inf             302.833         Inf         304.753          0.997786   0.997333
#    8 │     0.6      0.5      2     0.6     1.125           1.25152         3.125       3.29167        0.606281   0.468
#    9 │     0.6      0.5      3     0.4     0.156863        0.152446        2.15686     2.20761        0.407747   0.139667
#   10 │     0.6      0.5      4     0.3     0.0264641       0.0214861       2.02646     2.07795        0.301273   0.0366667
#   11 │     0.6      0.5      5     0.24    0.00432314      0.00159177      2.00432     1.97166        0.236018   0.004
#   12 │     0.6      0.5      6     0.2     0.00065054      0.000293079     2.00065     2.01909        0.202282   0.000666667
#   13 │     0.9      0.5      1     1.8   Inf            1294.01          Inf        1295.96           0.999711   0.999333
#   14 │     0.9      0.5      2     0.9     8.52632         4.30116        10.5263      6.25276        0.859426   0.789
#   15 │     0.9      0.5      3     0.6     0.591241        0.688087        2.59124     2.67861        0.593869   0.361
#   16 │     0.9      0.5      4     0.45    0.116849        0.162819        2.11685     2.23593        0.476388   0.172
#   17 │     0.9      0.5      5     0.36    0.0253107       0.0198672       2.02531     2.01795        0.357813   0.037
#   18 │     0.9      0.5      6     0.3     0.00530784      0.0128888       2.00531     2.00199        0.303804   0.0186667
